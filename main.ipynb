# %%
using Mimi, MimiFUND

# %%
m = MimiFUND.getmodel();

# %%
run(m)

# %%
explore(m, :climatedynamics, :temp)
# Out:
# WARN Can not resolve event source: window
# WARN Can not resolve event source: window
# WARN Can not resolve event source: window
# WARN Can not resolve event source: window
# VegaLite.VLSpec{:plot}
